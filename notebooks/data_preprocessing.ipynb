# %%
import pandas as pd

# %%
pwd
# Out:
# 'd:\\GitHub\\JOB-BSP\\notebooks'

# %%
df = pd.read_csv(r"..\datasets\raw_datasets_processed\train.csv")
df["priority"].value_counts()
# Out:
# priority
# Major       2078
# Minor        802
# Trivial      147
# Critical     132
# Blocker       39
# Name: count, dtype: int64
